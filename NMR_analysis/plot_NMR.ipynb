# %%
from simulation_B_spin_modified import w0
# from O17_simulation_NMR import O_data_file
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

# %%
# df = N_data_file()


# Fig, axes = plt.subplots(nrows=4, ncols=3,figsize=(16,12), sharey = 'row', sharex=True,constrained_layout=True)
# title = ['Z rotation','Y rotation','X rotation']
# for  i in range(3):
#     axes[i,0].set_ylabel(r'$Frequency\ (Hz)$')
#     axes[i+1, 0].set_ylabel(r'$Frequency\ (Hz)$')

#     axes[0,i].set_title(title[i])
#     axes[0,i].plot(df[i].angle,df[i].freq_1D, '-m', label = r'$|1>\leftrightarrow|0>$')
#     axes[0,i].plot(df[i].angle,df[i].freq_2D, '-r',label = r'$|0>\leftrightarrow|-1>$')
#     axes[0,i].legend(loc='best')
#     # axes[0,i].grid()

#     axes[1,i].plot(df[i].angle,df[i].freq_sum, '-g', label = r'$1>\leftrightarrow|0> + |0>\leftrightarrow|-1>$')
#     axes[1,i].legend(loc='best')
#     # axes[1,i].grid()

#     axes[2,i].plot(df[i].angle,df[i].freq_diff, '-', label = r'$|1>\leftrightarrow|0> - |0>\leftrightarrow|-1>$')
#     axes[2,i].set_xlim(left=0)
#     axes[2,i].legend(loc='best') 
#     # axes[2,i].grid()





#     axes[3,i].plot(df[i].angle,df[i].acs, '-', color='darkorange', label = r'$H_{Q, ACS_D}$')
#     axes[3,i].plot(df[i].angle,df[i].csa,'-', color = 'black', label = r'$H_{Q, CSA}$')
#     # axes[3,i].plot(df[i].angle,df[i].acs + df[i].csa, label = r'$H_{Q, ACS} +H_{Q, CSA} $')
#     axes[3,i].plot(df[i].angle,df[i].acs_anti, '-', color = 'green', label = r'$H_{Q, ACS_L}$')
#     axes[3,i].set_xlabel(r'$Angle\ (degrees)$')
#     axes[3,i].legend(loc='best')
#     # axes[3,i].grid()

# %% [markdown]
# **Plot B rotation**

# %%
title = ['x rotation', 'y rotation', 'z rotation']
dfs1 = [0]*len(title)
dfs2 = [0]*len(title)
file_path = ('/Users/shiva/Documents/Research/GitHub/Script_project/Data_simulation/')
# for set_index in range(301, 3):  # Update the range to match the available data sets
#     set_dfs = []  # List to store dataframes for the current set

for i, orientation in enumerate(title):
    file1 = f'{orientation}_set1_B_eQ.csv'       #Read file
    file2 = f'{orientation}_set2_B_eQ.csv'
    dfs1[i] = pd.read_csv(file_path+file1, index_col=0)
    dfs2[i] = pd.read_csv(file_path+file2, index_col=0)
    # file_name = f'{orientation}_set2_B11.csv'     Read file for other magnetic site
    # dfs2[i] = pd.read_csv(file_path+file_name, index_col=0)
# Append the set dataframes to the main list

# print(dfs2[1])
Fig, axes = plt.subplots(nrows=4, ncols=3,figsize=(16,12), sharex=True, sharey='row', constrained_layout=True)
Fig.suptitle(r' Plot for $(+,+){-}8-HQ(ipc)_2B$', fontsize=15)
for  i, orientation in enumerate(title):
    
    axes[i,0].set_ylabel('Chemical Shift \ MHz')
    axes[i+1, 0].set_ylabel('Chemical Shift \ Hz')

    axes[0,i].set_title(orientation)
    axes[0,i].plot(dfs1[i].angle,dfs1[i].freq_3212 / 1e6, '-m', label = r'$|3/2>\leftrightarrow|1/2> transition$') # frequency in MHz
    # axes[0,i].plot(dfs1[i].angle,dfs1[i].freq_1212 / 1e6, '-r',label = r'$1/2\leftrightarrow-1/2\ transition$')
    axes[0,i].plot(dfs1[i].angle,dfs1[i].freq_1212/ 1e4, '--', color = 'black', label = r'$1/2\leftrightarrow-1/2\ transition\ (x100)$')
    axes[0,i].plot(dfs1[i].angle,dfs1[i].freq_1232 / 1e6, color = '#008080',label = r'$|-1/2>\leftrightarrow|-3/2> transition$')
    axes[0,i].legend(loc='best')
    # axes[0,i].grid()

    axes[1,i].plot(dfs1[i].angle,dfs1[i].freq_sum / 1e6, '-g', label = r'$3/2>\leftrightarrow|1/2> + |1/2>\leftrightarrow|-1/2>+ |-1/2>\leftrightarrow|-3/2>$')
    axes[1,i].legend(loc='best')
    # axes[1,i].grid()

    axes[2,i].plot(dfs1[i].angle,dfs1[i].freq_diff / 1e6, '-', label = r'$|3/2>\leftrightarrow|1/2> - |-1/2>\leftrightarrow|-3/2>$')
    axes[2,i].set_xlim(left=0)
    axes[2,i].legend(loc='best') 
    # axes[2,i].grid()

    axes[3,i].plot(dfs1[i].angle,dfs1[i].acs, label = r'$H_{Q, ACS_D}$')
    axes[3,i].plot(dfs1[i].angle,dfs1[i].csa, '-', color = 'olive',label = r'$H_{Q, CSA}$')
    # axes[3,i].plot(df[i].angle,df[i].acs + df[i].csa, label = r'$H_{Q, ACS} +H_{Q, CSA} $')
    axes[3,i].plot(dfs1[i].angle,dfs2[i].acs,  '-', color='darkorange', label = r'$H_{Q, ACS_L}$')
    axes[3,i].set_xlabel('Angle \ degrees')
    axes[3,i].legend(loc='best')
    # axes[3,i].grid()

axes[0,2].yaxis.set_label_position("right")
axes[0,2].set_ylabel('Raw Data', fontweight='bold')

axes[1,2].yaxis.set_label_position("right")
axes[1,2].set_ylabel('Sum of frequencies', fontweight='bold')

axes[2,2].yaxis.set_label_position("right")
axes[2,2].set_ylabel('Difference of frequencies', fontweight='bold')

axes[3,2].yaxis.set_label_position("right")
axes[3,2].set_ylabel('ACS for L and D form', fontweight='bold')
# Out:
# Text(0, 0.5, 'ACS for L and D form')

# %% [markdown]
# **Plot for Raw Data and HQ-ACS**

# %%
title = ['x rotation', 'y rotation', 'z rotation']
dfs1 = [0]*len(title)
dfs2 = [0]*len(title)
file_path = ('/Users/shiva/Documents/Research/GitHub/Script_project/Data_simulation/')

for i, orientation in enumerate(title):
    file1 = f'{orientation}_set1_B_eQ.csv'       #Read file
    file2 = f'{orientation}_set2_B_eQ.csv'
    dfs1[i] = pd.read_csv(file_path+file1, index_col=0)
    dfs2[i] = pd.read_csv(file_path+file2, index_col=0)



Fig, axes = plt.subplots(nrows=2, ncols=3,figsize=(25, 15), sharex=True, sharey='row', constrained_layout=True)
for  i, orientation in enumerate(title):
    
    axes[0,0].set_ylabel('Chemical Shift / MHz', fontsize = 25)
    axes[1, 0].set_ylabel('Chemical Shift / Hz', fontsize = 25)

    axes[0,i].plot(dfs1[i].angle,dfs1[i].freq_3212 / 1e6, '-', color = '#009E73' ,
                   label = r'$|3/2>\leftrightarrow|1/2> transition$') # frequency in MHz
   
    axes[0,i].plot(dfs1[i].angle,dfs1[i].freq_1212/ 1e4, '--', color = 'black', 
                   label = r'$|1/2>\leftrightarrow|-1/2>\ transition\ (x100)$')
    
    axes[0,i].plot(dfs1[i].angle,dfs1[i].freq_1212 / 1e6, '-', color = 'black', 
                   label = r'$|1/2>\leftrightarrow|-1/2>\ transition$')
    
    axes[0,i].plot(dfs1[i].angle,dfs1[i].freq_1232 / 1e6, color='#D55E00',
                   label = r'$|-1/2>\leftrightarrow|-3/2> transition$')
    
    point = 55  # point chosen on plot
    x_label = dfs1[i].angle[point]
    y_label = 10*dfs1[i].freq_1212[point] / 1e6
    axes[0,i].text(x_label - 5, y_label - 0.6, 'CT×100', color='#000000', fontsize=25)
    axes[0,i].legend(loc='upper left',fontsize = 12, ncol = 2)


    axes[1,i].plot(dfs1[i].angle,dfs1[i].acs, '-', color = 'blue', 
                   label = r'$H_{Q, ACS-D}$')
    
    axes[1,i].plot(dfs1[i].angle,dfs1[i].csa, '-', color = 'gray',
                   label = r'$H_{Q, CSA}$')
    
    axes[1,i].plot(dfs1[i].angle,dfs2[i].acs,  '-', color='#c1272d', 
                   label = r'$H_{Q, ACS-L}$')
    axes[1,i].set_xlabel('Angle / degrees', fontsize = 25)
    axes[1,i].legend(loc='upper left',fontsize = 14, ncol = 3)
    # axes[3,i].grid()
    
axes[0,0].set_title(r'-$x^T$ rotation', fontsize = 25)
axes[0,1].set_title(r'$y^T$ rotation', fontsize = 25)
axes[0,2].set_title(r'-$z^T$ rotation', fontsize = 25)
axes[0,2].yaxis.set_label_position("right")
# axes[0,2].set_ylabel('Raw Data', fontweight='bold', fontsize = 15)


axes[1,2].yaxis.set_label_position("right")
# axes[1,2].set_ylabel('ACS for L and D form', fontweight='bold', fontsize = 15)

plt.savefig('/Users/shiva/Documents/Research/GitHub/Script_project/NMR_analysis/plots_experiment/simulation_central_satellite_ACS_CSA.png', 
            dpi = 150 ,
            bbox_inches='tight')
plt.show()

# %%
# Create 1 row with 3 columns
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25, 10), sharex=True, sharey=True, constrained_layout=True)
fig.suptitle(r'Simulation for $^{11}B$ in $(+,+)\!-\!8\!-\!HQ(ipc)_2B$', fontsize=22)

for i, orientation in enumerate(title):
    
    axes[i].plot(dfs1[i].angle, dfs1[i].freq_3212 / 1000, linestyle = 'dotted', color = 'm', label=r'$|3/2>\leftrightarrow|1/2>$')
    axes[i].plot(dfs1[i].angle, dfs1[i].freq_1212 / 1000, '-r', label=r'$|1/2>\leftrightarrow|-1/2>$')
    axes[i].plot(dfs1[i].angle, dfs1[i].freq_1232 / 1000, linestyle = 'dashdot', color='#008080', label=r'$|-1/2>\leftrightarrow|-3/2>$')
    axes[i].set_xlabel('Angle \ degrees', fontsize = 22)
    axes[i].tick_params(axis='x', labelsize=16)
    
    axes[i].legend(loc='upper left', fontsize = 13, ncol = 3)
axes[0].set_title(r'-$x^T$ rotation', fontsize = 22)
axes[1].set_title(r'$y^T$ rotation', fontsize = 22)
axes[2].set_title(r'-$z^T$ rotation', fontsize = 22)
axes[0].set_ylabel('Chemical Shift \ kHz', fontsize = 22)
axes[0].tick_params(axis='y', labelsize=16)
axes[2].yaxis.set_label_position("right")
# axes[2].set_ylabel('Raw Data', fontweight='bold', fontsize = 16)

# plt.savefig('/Users/shiva/Documents/Research/GitHub/Script_project/NMR_analysis/plots_experiment/DHQ_simulation2.png', dpi = 150 ,bbox_inches='tight')
plt.show()

# %% [markdown]
# **Plot for Manuscript**

# %%
# Create 1 row with 3 columns
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25, 15), sharex=True, sharey=True, constrained_layout=True)
# fig.suptitle(r'Simulation for $^{11}B$ in $(+,+)\!-\!8\!-\!HQ(ipc)_2B$', fontsize=22)
title = ['x rotation', 'y rotation', 'z rotation']
dfs1 = [0]*len(title)
dfs2 = [0]*len(title)
file_path = ('/Users/shiva/Documents/Research/GitHub/Script_project/Data_simulation/')


for i, orientation in enumerate(title):
    file1 = f'{orientation}_set1_B.csv'       #Read file
    file2 = f'{orientation}_set2_B.csv'       #Read file
    dfs1[i] = pd.read_csv(file_path+file1, index_col=0)
    dfs2[i] = pd.read_csv(file_path+file2, index_col=0)
    
    #Plotting
    axes[i].plot(dfs1[i].angle, dfs1[i].freq_3212 / 1000, 
                 linestyle = '-', 
                 color = '#009E73', 
                 linewidth = 3)
    axes[i].plot(dfs1[i].angle, dfs1[i].freq_1212 / 1000, 
                 linestyle = '-', 
                 color = '#0072B2',
                 linewidth =3)
    axes[i].plot(dfs1[i].angle, dfs1[i].freq_1232 / 1000, 
                 linestyle = '-', 
                 color='#D55E00',
                 linewidth = 3)
    axes[i].plot(dfs1[i].angle, 10*dfs1[i].freq_1212 / 1000, 
                 linestyle = '--', 
                 color = '#0072B2',
                 linewidth = 3)
    axes[i].set_xlabel('Angle \ degrees', fontsize = 25)
    axes[i].tick_params(axis='x', labelsize=18)
    # index = 30
    # x_position = x_array[index]
    # y_position = y_array[index]
    axes[i].text(5, -30, 'x10', color='#0072B2', fontsize=25)
    
    # axes[i].legend(loc='upper left', fontsize = 13, ncol = 3)
axes[0].set_title(r'-$x^T$ rotation', fontsize = 25)
axes[1].set_title(r'$y^T$ rotation', fontsize = 25)
axes[2].set_title(r'-$z^T$ rotation', fontsize = 25)
axes[0].set_ylabel('Chemical Shift \ kHz', fontsize = 25)
axes[0].tick_params(axis='y', labelsize=18)
# Add text label near the line


axes[2].yaxis.set_label_position("right")
# axes[2].set_ylabel('Raw Data', fontweight='bold', fontsize = 16)

plt.savefig('/Users/shiva/Documents/Research/GitHub/Script_project/NMR_analysis/plots_experiment/DHQ_simulation_central_satellite_10x.png', 
            dpi = 150 ,
            bbox_inches='tight')
plt.show()


# # New figure for only central transition
# fig2, ax = plt.subplots(nrows=1, ncols=3,figsize=(25,15), sharex=True, sharey=True, constrained_layout=True)
# colors = ['r', 'g', 'b']  # Optional: color for each orientation

# for i, orientation in enumerate(title):
#     ax[i].plot(dfs1[i].angle, dfs1[i].freq_1212 / 1000, label=orientation, color=colors[i], linewidth=2)

#     ax[i].set_xlabel('Angle \ degrees', fontsize=22)
# ax[0].set_ylabel('Chemical Shift \ kHz', fontsize=22)

# ax[0].set_title(r'-$x^T$ rotation', fontsize = 22)
# ax[1].set_title(r'$y^T$ rotation', fontsize = 22)
# ax[2].set_title(r'-$z^T$ rotation', fontsize = 22)
# ax[0].tick_params(axis='both', labelsize=14)

# plt.tight_layout()
# plt.savefig('/Users/shiva/Documents/Research/GitHub/Script_project/NMR_analysis/plots_experiment/DHQ_central.png', dpi=150, bbox_inches='tight')
# plt.show()

# %% [markdown]
# **Plot for eQ included data**

# %%
# Create 1 row with 3 columns
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25, 15), sharex=True, sharey=True, constrained_layout=True)
# fig.suptitle(r'Simulation for $^{11}B$ in $(+,+)\!-\!8\!-\!HQ(ipc)_2B$', fontsize=22)
title = ['x rotation', 'y rotation', 'z rotation']
dfs1 = [0]*len(title)
dfs2 = [0]*len(title)
file_path = ('/Users/shiva/Documents/Research/GitHub/Script_project/Data_simulation/')


for i, orientation in enumerate(title):
    file1 = f'{orientation}_set1_B_eQ.csv'       #Read file
    file2 = f'{orientation}_set2_B_eQ.csv'       #Read file
    dfs1[i] = pd.read_csv(file_path+file1, index_col=0)
    dfs2[i] = pd.read_csv(file_path+file2, index_col=0)
    
    #Plotting
    axes[i].plot(dfs1[i].angle, dfs1[i].freq_3212 / 10**6, 
                 linestyle = '-', 
                 color = '#009E73', 
                 linewidth = 3)
    axes[i].plot(dfs1[i].angle, dfs1[i].freq_1212 / 10**6, 
                 linestyle = '-', 
                 color = '#000000',
                 linewidth =3)
    axes[i].plot(dfs1[i].angle, dfs1[i].freq_1232 / 10**6, 
                 linestyle = '-', 
                 color='#D55E00',
                 linewidth = 3)
    axes[i].plot(dfs1[i].angle, 100*dfs1[i].freq_1212 / 10**6, 
                 linestyle = '--', 
                 color = '#000000',
                 linewidth = 3)
    # Add horizontal band for experimental range
    ymin = -19/1000 #frequency in MHz
    ymax = 19/1000. #frequency in MHz
    # axes[i].axhspan(ymin, ymax, color='lightgray', alpha=1)

    axes[i].set_xlabel('Angle / degrees', fontsize = 25)
    axes[i].tick_params(axis='x', labelsize=18)
    point = 55  # point chosen on plot
    x_label = dfs1[i].angle[point]
    y_label = 10*dfs1[i].freq_1212[point] / 1e6
    axes[i].text(x_label - 5, y_label - 0.55, 'CT×100', color='#000000', fontsize=25)

    
    # axes[i].legend(loc='upper left', fontsize = 13, ncol = 3)
axes[0].set_title(r'-$x^T$ rotation', fontsize = 25)
axes[1].set_title(r'$y^T$ rotation', fontsize = 25)
axes[2].set_title(r'-$z^T$ rotation', fontsize = 25)
axes[0].set_ylabel('Chemical Shift / MHz', fontsize = 25)
axes[0].tick_params(axis='y', labelsize=18)
# Add text label near the line

axes[2].yaxis.set_label_position("right")


plt.savefig('/Users/shiva/Documents/Research/GitHub/Script_project/NMR_analysis/plots_experiment/DHQ_simulation_central_satellite_eQ_included_100x_2.png', 
            dpi = 150 ,
            bbox_inches='tight')
plt.show()

# %% [markdown]
# **Inset Plot**

# %%
# Create 1 row with 3 columns
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(30, 20), sharex=True, sharey=True, constrained_layout=True)
# fig.suptitle(r'Simulation for $^{11}B$ in $(+,+)\!-\!8\!-\!HQ(ipc)_2B$', fontsize=22)
title = ['x rotation', 'y rotation', 'z rotation']
dfs1 = [0]*len(title)
dfs2 = [0]*len(title)
file_path = ('/Users/shiva/Documents/Research/GitHub/Script_project/Data_simulation/')


for i, orientation in enumerate(title):
    file1 = f'{orientation}_set1_B_eQ.csv'       #Read file
    file2 = f'{orientation}_set2_B_eQ.csv'       #Read file
    dfs1[i] = pd.read_csv(file_path+file1, index_col=0)
    dfs2[i] = pd.read_csv(file_path+file2, index_col=0)
    
    #Plotting
    axes[i].plot(dfs1[i].angle, dfs1[i].freq_3212 / 1000, 
                 linestyle = 'dotted', 
                 color = '#009E73', 
                 linewidth = 5)
    axes[i].plot(dfs1[i].angle, dfs1[i].freq_1212 / 1000, 
                 linestyle = '-', 
                 color = '#0072B2',
                 linewidth = 5)
    axes[i].plot(dfs1[i].angle, dfs1[i].freq_1232 / 1000, 
                 linestyle = 'dashdot', 
                 color='#E69F00',
                 linewidth = 5)
    axes[i].set_xlabel('Angle \ degrees', fontsize = 25)
    axes[i].tick_params(axis='x', labelsize=18)
    
    # axes[i].legend(loc='upper left', fontsize = 13, ncol = 3)
axes[0].set_title(r'-$x^T$ rotation', fontsize = 25)
axes[1].set_title(r'$y^T$ rotation', fontsize = 25)
axes[2].set_title(r'-$z^T$ rotation', fontsize = 25)
axes[0].set_ylabel('Chemical Shift \ kHz', fontsize = 25)
axes[0].tick_params(axis='y', labelsize=18)
axes[2].yaxis.set_label_position("right")
# axes[2].set_ylabel('Raw Data', fontweight='bold', fontsize = 16)

# plt.savefig('/Users/shiva/Documents/Research/GitHub/Script_project/NMR_analysis/plots_experiment/DHQ_simulation_central_satellite.png', dpi = 150 ,bbox_inches='tight')



# New figure for only central transition
for i, ax in enumerate(axes):
    ax_inset = inset_axes(ax, 
                          width=6.5, height=1.5,  # in inches 
                          loc='upper right', 
                          bbox_to_anchor=(0.77, 1), 
                          bbox_transform=ax.transAxes,
                          borderpad=1)

        # Plot only the central transition
    ax_inset.plot(dfs1[i].angle, dfs1[i].freq_1212 / 1000, color='#0072B2', linewidth=3)
    # ax_inset.set_title(f"{title[i]}", fontsize=12)
    ax_inset.tick_params(axis='both', labelsize=12)

    # Optional: improve readability
    # ax_inset.set_xlabel('Angle', fontsize=10)
    # ax_inset.set_ylabel('1212 (kHz)', fontsize=10)
# plt.tight_layout()
# plt.savefig('/Users/shiva/Documents/Research/GitHub/Script_project/NMR_analysis/plots_experiment/DHQ_central_satellite_inset.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
x = min(dfs1[0].freq_2D/w0)
y = max(dfs1[0].freq_2D/w0)
print(x,y)
x_exp = -14.54
y_exp = -33.44
z1 = x/x_exp
z2 = y/y_exp
print(z1, z2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/b2/nnj_p1yj37ndxjjfx5yk1ccm0000gn/T/ipykernel_22340/433590216.py in ?()
# ----> 1 x = min(dfs1[0].freq_2D/w0)
#       2 y = max(dfs1[0].freq_2D/w0)
#       3 print(x,y)
#       4 x_exp = -14.54
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'freq_2D'

# %%
Fig, axes = plt.subplots(nrows=4, ncols=3,figsize=(16,12), sharex=True,sharey='row', constrained_layout=True)
Fig.suptitle(' Plot for Magnetic Site #2', fontsize=15)
for  i, orientation in enumerate(title):
    axes[i,0].set_ylabel(r'$Frequency\ (Hz)$')
    axes[i+1, 0].set_ylabel(r'$Frequency\ (Hz)$')

    axes[0,i].set_title(orientation)
    axes[0,i].plot(dfs2[i].angle,dfs2[i].freq_1D, '-m', label = r'$|3/2>\leftrightarrow|1/2> transition$')
    axes[0,i].plot(dfs2[i].angle,dfs2[i].freq_2D, '-r',label = r'$|1/2>\leftrightarrow|-1/2> transition$')
    axes[0,i].plot(dfs2[i].angle,dfs2[i].freq_3D, '-b',label = r'$|-1/2>\leftrightarrow|-3/2> transition$')
    axes[0,i].legend(loc='best')
    axes[0,i].grid()

    axes[1,i].plot(dfs2[i].angle,dfs2[i].freq_sum, '-g', label = r'$3/2>\leftrightarrow|1/2> + |1/2>\leftrightarrow|-1/2>+ |-1/2>\leftrightarrow|-3/2>$')
    axes[1,i].legend(loc='best')
    axes[1,i].grid()

    axes[2,i].plot(dfs2[i].angle,dfs2[i].freq_diff, '-', label = r'$|3/2>\leftrightarrow|1/2> - |-1/2>\leftrightarrow|-3/2>$')
    axes[2,i].set_xlim(left=0)
    axes[2,i].legend(loc='best') 
    axes[2,i].grid()

    axes[3,i].plot(dfs2[i].angle,dfs2[i].acs, label = r'$H_{Q, ACS_D}$')
    axes[3,i].plot(dfs2[i].angle,dfs2[i].csa, '-', color = 'olive',label = r'$H_{Q, CSA}$')
    # axes[3,i].plot(df[i].angle,df[i].acs + df[i].csa, label = r'$H_{Q, ACS} +H_{Q, CSA} $')
    axes[3,i].plot(dfs2[i].angle,dfs2[i].acs_anti,  '-', color='darkorange', label = r'$H_{Q, ACS_L}$')
    axes[3,i].set_xlabel(r'$Angle\ (degrees)$')
    axes[3,i].legend(loc='best')
    axes[3,i].grid()


axes[0,2].yaxis.set_label_position("right")
axes[0,2].set_ylabel('Raw Data', fontweight='bold')

axes[1,2].yaxis.set_label_position("right")
axes[1,2].set_ylabel('Sum of frequencies', fontweight='bold')

axes[2,2].yaxis.set_label_position("right")
axes[2,2].set_ylabel('Difference of frequencies', fontweight='bold')

axes[3,2].yaxis.set_label_position("right")
axes[3,2].set_ylabel('ACS for L and D form', fontweight='bold')

# %%
df = O_data_file()


Fig, axes = plt.subplots(nrows=4, ncols=3,figsize=(16,12), sharex=True,sharey='row', constrained_layout=True)
title = ['Z rotation','Y rotation','X rotation']
for  i in range(3):
    axes[i,0].set_ylabel(r'$Frequency\ (Hz)$')
    axes[i+1, 0].set_ylabel(r'$Frequency\ (Hz)$')

    axes[0,i].set_title(title[i])
    axes[0,i].plot(df[i].angle,df[i].freq_1D, '-m', label = r'$|5/2>\leftrightarrow|3/2> transition$')
    axes[0,i].plot(df[i].angle,df[i].freq_2D, '-r',label = r'$|3/2>\leftrightarrow|1/2> transition$')
    axes[0,i].plot(df[i].angle,df[i].freq_3D, '-b',label = r'$|1/2>\leftrightarrow|-1/2> transition$')
    axes[0,i].plot(df[i].angle,df[i].freq_4D, '-c',label = r'$|-1/2>\leftrightarrow|-3/2> transition$')
    axes[0,i].plot(df[i].angle,df[i].freq_5D, '-g',label = r'$|-3/2>\leftrightarrow|-5/2> transition$')

    axes[0,i].legend(loc='best')
    axes[0,i].grid()

    # axes[1,i].plot(df[i].angle,df[i].freq_sum, '-g', label = r'$3/2>\leftrightarrow|1/2> + |1/2>\leftrightarrow|-1/2>+ |-1/2>\leftrightarrow|-3/2>$')
    # axes[1,i].legend(loc='best')
    # axes[1,i].grid()

    # axes[2,i].plot(df[i].angle,df[i].freq_diff, '-', label = r'$|3/2>\leftrightarrow|1/2> - |-1/2>\leftrightarrow|-3/2>$')
    # axes[2,i].set_xlim(left=0)
    # axes[2,i].legend(loc='best') 
    # axes[2,i].grid()





    axes[3,i].plot(df[i].angle,df[i].acs, label = r'$H_{Q, ACS_D}$')
    axes[3,i].plot(df[i].angle,df[i].csa, '-', color = 'olive',label = r'$H_{Q, CSA}$')
    # axes[3,i].plot(df[i].angle,df[i].acs + df[i].csa, label = r'$H_{Q, ACS} +H_{Q, CSA} $')
    axes[3,i].plot(df[i].angle,df[i].acs_anti,  '-', color='darkorange', label = r'$H_{Q, ACS_L}$')
    axes[3,i].set_xlabel(r'$Angle\ (degrees)$')
    axes[3,i].legend(loc='best')
    axes[3,i].grid()

# %%
def gaussian(x, a, b, c):
    f = a*np.exp(-((x-b)**2)/2*c**2)
    return f

# %%
fig = plt.figure(dpi = 150)
ax = fig.add_subplot(111)
x = np.arange(-50, 50, 1)
y1 = gaussian(x, 10, 20, 1)
y2 = gaussian(x, 10, -20, 1)
ax.set_yticks([])
ax.set_xticks([])

plt.plot(x,y1, color = 'black')
plt.plot(x,y2, color = 'black')

ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)

# ax.set_xlabel(r'$Chemical\ Shift\ (\delta)$', fontsize=13)
plt.show()
