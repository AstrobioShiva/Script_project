# %%
from spin1_simulation_NMR import N_data_file
from B_simulation_NMR import B_data_file
from O17_simulation_NMR import O_data_file
# Out:
# Welcome to JupyROOT 6.26/06
# iminuit version: 2.17.0

# %%
df = N_data_file()

import matplotlib.pyplot as plt
Fig, axes = plt.subplots(nrows=4, ncols=3,figsize=(16,12), sharey = 'row', sharex=True,constrained_layout=True)
title = ['Z rotation','Y rotation','X rotation']
for  i in range(3):
    axes[i,0].set_ylabel(r'$Frequency\ (Hz)$')
    axes[i+1, 0].set_ylabel(r'$Frequency\ (Hz)$')

    axes[0,i].set_title(title[i])
    axes[0,i].plot(df[i].angle,df[i].freq_1D, '-m', label = r'$|1>\leftrightarrow|0>$')
    axes[0,i].plot(df[i].angle,df[i].freq_2D, '-r',label = r'$|0>\leftrightarrow|-1>$')
    axes[0,i].legend(loc='best')
    # axes[0,i].grid()

    axes[1,i].plot(df[i].angle,df[i].freq_sum, '-g', label = r'$1>\leftrightarrow|0> + |0>\leftrightarrow|-1>$')
    axes[1,i].legend(loc='best')
    # axes[1,i].grid()

    axes[2,i].plot(df[i].angle,df[i].freq_diff, '-', label = r'$|1>\leftrightarrow|0> - |0>\leftrightarrow|-1>$')
    axes[2,i].set_xlim(left=0)
    axes[2,i].legend(loc='best') 
    # axes[2,i].grid()





    axes[3,i].plot(df[i].angle,df[i].acs, '-', color='darkorange', label = r'$H_{Q, ACS_D}$')
    axes[3,i].plot(df[i].angle,df[i].csa,'-', color = 'black', label = r'$H_{Q, CSA}$')
    # axes[3,i].plot(df[i].angle,df[i].acs + df[i].csa, label = r'$H_{Q, ACS} +H_{Q, CSA} $')
    axes[3,i].plot(df[i].angle,df[i].acs_anti, '-', color = 'green', label = r'$H_{Q, ACS_L}$')
    axes[3,i].set_xlabel(r'$Angle\ (degrees)$')
    axes[3,i].legend(loc='best')
    # axes[3,i].grid()

# %%
df = B_data_file()

import matplotlib.pyplot as plt
Fig, axes = plt.subplots(nrows=4, ncols=3,figsize=(16,12), sharex=True,constrained_layout=True)
title = ['Z rotation','Y rotation','X rotation']
for  i in range(3):
    axes[i,0].set_ylabel(r'$Frequency\ (Hz)$')
    axes[i+1, 0].set_ylabel(r'$Frequency\ (Hz)$')

    axes[0,i].set_title(title[i])
    axes[0,i].plot(df[i].angle,df[i].freq_1D, '-m', label = r'$|3/2>\leftrightarrow|1/2> transition$')
    axes[0,i].plot(df[i].angle,df[i].freq_2D, '-r',label = r'$|1/2>\leftrightarrow|-1/2> transition$')
    axes[0,i].plot(df[i].angle,df[i].freq_3D, '-b',label = r'$|-1/2>\leftrightarrow|-3/2> transition$')
    axes[0,i].legend(loc='best')
    axes[0,i].grid()

    axes[1,i].plot(df[i].angle,df[i].freq_sum, '-g', label = r'$3/2>\leftrightarrow|1/2> + |1/2>\leftrightarrow|-1/2>+ |-1/2>\leftrightarrow|-3/2>$')
    axes[1,i].legend(loc='best')
    axes[1,i].grid()

    axes[2,i].plot(df[i].angle,df[i].freq_diff, '-', label = r'$|3/2>\leftrightarrow|1/2> - |-1/2>\leftrightarrow|-3/2>$')
    axes[2,i].set_xlim(left=0)
    axes[2,i].legend(loc='best') 
    axes[2,i].grid()





    axes[3,i].plot(df[i].angle,df[i].acs, label = r'$H_{Q, ACS_D}$')
    axes[3,i].plot(df[i].angle,df[i].csa, '-', color = 'olive',label = r'$H_{Q, CSA}$')
    # axes[3,i].plot(df[i].angle,df[i].acs + df[i].csa, label = r'$H_{Q, ACS} +H_{Q, CSA} $')
    axes[3,i].plot(df[i].angle,df[i].acs_anti,  '-', color='darkorange', label = r'$H_{Q, ACS_L}$')
    axes[3,i].set_xlabel(r'$Angle\ (degrees)$')
    axes[3,i].legend(loc='best')
    axes[3,i].grid()

# %%
df = O_data_file()

import matplotlib.pyplot as plt
Fig, axes = plt.subplots(nrows=4, ncols=3,figsize=(16,12), sharex=True,constrained_layout=True)
title = ['Z rotation','Y rotation','X rotation']
for  i in range(3):
    axes[i,0].set_ylabel(r'$Frequency\ (Hz)$')
    axes[i+1, 0].set_ylabel(r'$Frequency\ (Hz)$')

    axes[0,i].set_title(title[i])
    axes[0,i].plot(df[i].angle,df[i].freq_1D, '-m', label = r'$|5/2>\leftrightarrow|3/2> transition$')
    axes[0,i].plot(df[i].angle,df[i].freq_2D, '-r',label = r'$|3/2>\leftrightarrow|1/2> transition$')
    axes[0,i].plot(df[i].angle,df[i].freq_3D, '-b',label = r'$|1/2>\leftrightarrow|-1/2> transition$')
    axes[0,i].plot(df[i].angle,df[i].freq_4D, '-c',label = r'$|-1/2>\leftrightarrow|-3/2> transition$')
    axes[0,i].plot(df[i].angle,df[i].freq_5D, '-g',label = r'$|-3/2>\leftrightarrow|-5/2> transition$')

    axes[0,i].legend(loc='best')
    axes[0,i].grid()

    # axes[1,i].plot(df[i].angle,df[i].freq_sum, '-g', label = r'$3/2>\leftrightarrow|1/2> + |1/2>\leftrightarrow|-1/2>+ |-1/2>\leftrightarrow|-3/2>$')
    # axes[1,i].legend(loc='best')
    # axes[1,i].grid()

    # axes[2,i].plot(df[i].angle,df[i].freq_diff, '-', label = r'$|3/2>\leftrightarrow|1/2> - |-1/2>\leftrightarrow|-3/2>$')
    # axes[2,i].set_xlim(left=0)
    # axes[2,i].legend(loc='best') 
    # axes[2,i].grid()





    axes[3,i].plot(df[i].angle,df[i].acs, label = r'$H_{Q, ACS_D}$')
    axes[3,i].plot(df[i].angle,df[i].csa, '-', color = 'olive',label = r'$H_{Q, CSA}$')
    # axes[3,i].plot(df[i].angle,df[i].acs + df[i].csa, label = r'$H_{Q, ACS} +H_{Q, CSA} $')
    axes[3,i].plot(df[i].angle,df[i].acs_anti,  '-', color='darkorange', label = r'$H_{Q, ACS_L}$')
    axes[3,i].set_xlabel(r'$Angle\ (degrees)$')
    axes[3,i].legend(loc='best')
    axes[3,i].grid()

# %%
# title = ['Z rotation','Y rotation','X rotation']
# rows = 5
# col = len(title)
# Fig, axes = plt.subplots(nrows=rows, ncols=col,figsize=(16,14), sharey = 'row', sharex=True,constrained_layout=True)

# for  i in range(3):
#     for j in range(rows):
#         axes[j,0].set_ylabel(r'$Frequency\ (Hz)$')
#     # axes[i+1, 0].set_ylabel(r'$Frequency\ (Hz)$')
#     axes[0,0].set_ylabel(r'$Frequency\ (MHz)$')
#     axes[1,0].set_ylabel(r'$Frequency\ (MHz)$')
                         
#     axes[0,i].set_title(title[i])
#     axes[0,i].plot(df[i].angle,df[i].freq_1D/1E6, '-m', label = r'$|1>\leftrightarrow|0>$')
#     axes[0,i].plot(df[i].angle,df[i].freq_2D/1E6, '-r',label = r'$|0>\leftrightarrow|-1>$')
#     axes[0,i].legend(loc='best')

#     # axes[0,i].grid()

#     # axes[1,i].plot(df[i].angle,df[i].freq_sum, '-g', label = r'$1>\leftrightarrow|0> + |0>\leftrightarrow|-1>$')
#     # axes[1,i].legend(loc='best')
#     # # axes[1,i].grid()

#     axes[1,i].plot(df[i].angle,df[i].freq_diff/1E6, '-', label = r'$|1>\leftrightarrow|0> - |0>\leftrightarrow|-1>$')
#     axes[1,i].set_xlim(left=0)
#     axes[1,i].legend(loc='best') 


#     axes[2,i].plot(df[i].angle,df[i].csa, '-', color='orchid', label = r'$H_{Q, CSA}$')
#     axes[2,i].set_xlim(left=0)
#     axes[2,i].legend(loc='best')





#     axes[3,i].plot(df[i].angle,df[i].acs, '-', color='darkorange', label = r'$H_{Q, ACS_D}$')
#     # axes[3,i].plot(df[i].angle,df[i].csa,'-', color = 'black', label = r'$H_{Q, CSA}$')
#     # axes[3,i].plot(df[i].angle,df[i].acs + df[i].csa, '-',  color = 'orchid', label = r'$H_{Q, ACS_D} +H_{Q, CSA} $')

#     axes[3,i].legend(loc='best')

#     axes[4,i].plot(df[i].angle,df[i].acs_anti, '-', color = 'lawngreen', label = r'$H_{Q, ACS_L}$')
#     # axes[4,i].plot(df[i].angle,df[i].csa,'-', color = 'black', label = r'$H_{Q, CSA}$')
#     # axes[4,i].plot(df[i].angle,df[i].acs_anti + df[i].csa, '-',  color = 'orchid', label = r'$H_{Q, ACS_L} +H_{Q, CSA} $')
#     axes[4,i].legend(loc='best')
#     axes[4,i].set_xlabel(r'$Angle\ (degrees)$')
#     # axes[3,i].grid()

# # ax1 = axes[0,2].twinx()
# # ax1 = subplot(1,1,1, sharex=axL, frameon=False)
# axes[0,2].yaxis.set_label_position("right")
# axes[0,2].set_ylabel('Raw Data', fontweight='bold')

# axes[1,2].yaxis.set_label_position("right")
# axes[1,2].set_ylabel('Difference', fontweight='bold')

# axes[2,2].yaxis.set_label_position("right")
# axes[2,2].set_ylabel('CSA', fontweight='bold')

# axes[3,2].yaxis.set_label_position("right")
# axes[3,2].set_ylabel('ACS for D form', fontweight='bold')

# axes[4,2].yaxis.set_label_position("right")
# axes[4,2].set_ylabel('ACS for L form', fontweight='bold')

# %%
# df = data_file()

# import matplotlib.pyplot as plt
# Fig, axes = plt.subplots(nrows=3, ncols=3,figsize=(16,12), sharey = 'row', sharex=True,constrained_layout=True)
# title = ['Z rotation','Y rotation','X rotation']
# for  i in range(3):
#     axes[i,0].set_ylabel(r'$Frequency\ (Hz)$')
#     # axes[i+1, 0].set_ylabel(r'$Frequency\ (Hz)$')

#     axes[0,i].set_title(title[i])
#     axes[0,i].plot(df[i].angle,df[i].freq_1D, '-m', label = r'$|1>\leftrightarrow|0>$')
#     axes[0,i].plot(df[i].angle,df[i].freq_2D, '-r',label = r'$|0>\leftrightarrow|-1>$')
#     axes[0,i].legend(loc='best')
#     # axes[0,i].grid()

#     axes[1,i].plot(df[i].angle,df[i].freq_sum, '-g', label = r'$1>\leftrightarrow|0> + |0>\leftrightarrow|-1>$')
#     axes[1,i].legend(loc='best')
#     # axes[1,i].grid()

#     axes[2,i].plot(df[i].angle,df[i].freq_diff, '-', label = r'$|1>\leftrightarrow|0> - |0>\leftrightarrow|-1>$')
#     axes[2,i].set_xlim(left=0)
#     axes[2,i].legend(loc='best') 
#     # axes[2,i].set_xlabel(r'$Angle\ (degrees)$')
#     # axes[2,i].grid()


# Fig, axes = plt.subplots(nrows=2, ncols=3,figsize=(16,10), sharey = 'row', sharex=True,constrained_layout=True)
# title = ['Z rotation','Y rotation','X rotation']
# for i in range(0,3):


#     axes[0,i].plot(df[i].angle,df[i].acs, '-', color='darkorange', label = r'$H_{Q, ACS_D}$')
#     axes[0,i].plot(df[i].angle,df[i].csa,'-', color = 'black', label = r'$H_{Q, CSA}$')
#     axes[0,i].legend(loc='best')
#     # axes[3,i].plot(df[i].angle,df[i].acs + df[i].csa, label = r'$H_{Q, ACS} +H_{Q, CSA} $')
#     axes[1,i].plot(df[i].angle,df[i].csa,'-', color = 'black', label = r'$H_{Q, CSA}$')
#     axes[1,i].plot(df[i].angle,df[i].acs_anti, '-', color = 'green', label = r'$H_{Q, ACS_L}$')
#     axes[1,i].set_xlabel(r'$Angle\ (degrees)$')
#     axes[1,i].legend(loc='best')
#     # axes[3,i].grid()
