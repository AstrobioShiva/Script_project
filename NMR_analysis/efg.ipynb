# %%
efg = np.zeros((3, 3 ))                             # EFG Tensor from magres (in a.u.)
efg[0,0]= -509.730154; efg[0,1]= 0.031556; efg[0,2]=  0.088581;
efg[1,0]= efg[0,1]; efg[1,1]= -509.474454; efg[1,2]= 0.030556;
efg[2,0]= efg[0,2]; efg[2,1]= efg[1,2]; efg[2,2]= -509.506854;

eigenvalues, eigenvectors = np.linalg.eig(efg)

print(eigenvalues)
# Out:
# [-509.7624046  -509.43535742 -509.51369997]
