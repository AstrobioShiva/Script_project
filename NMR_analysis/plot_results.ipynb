# %% [markdown]
# **L-alanine Results**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


plt.figure(figsize=(8,5), dpi=200)

# df = pd.DataFrame({"id":["this study", "computed", "Pike et. al.", "Yamauchi et. al."], 
#                  # Cq data
#                    "Cq1Lala":[6.5, 8.34, 7.86, 8.1], 
#                    "Cq2Lala":[6.6, 6.36, 6.53, 7.2],
                   
#                    "sdCq1Lala":[0.4,0,0.05,0.3],
#                    "sdCq2Lala":[0.4,0,0.05,0.3]}
#                   )

plt.errorbar(np.arange(len(df['id'])), df['Cq1Lala'], yerr=df['sdCq1Lala'], ls = 'None', 
             marker='o', color = 'r', markersize=8, label = 'Site 1')
plt.errorbar(np.arange(len(df['id'])), df['Cq2Lala'], yerr=df['sdCq2Lala'], ls = 'None', 
             marker='o', color = 'b', markersize=8, label = 'Site 2')



ax = plt.gca()
ax.xaxis.set_ticks(np.arange(len(df['id'])))
ax.xaxis.set_ticklabels(df['id'], rotation=90, fontsize = 16)

# plt.xlabel("id", fontsize = 16)
plt.ylabel("Cq / MHz", fontsize = 16)

plt.legend(loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 17
#       6 plt.figure(figsize=(8,5), dpi=200)
#       8 # df = pd.DataFrame({"id":["this study", "computed", "Pike et. al.", "Yamauchi et. al."],
#       9 #                  # Cq data
#      10 #                    "Cq1Lala":[6.5, 8.34, 7.86, 8.1],
#    (...)
#      14 #                    "sdCq2Lala":[0.4,0,0.05,0.3]}
#      15 #                   )
# ---> 17 plt.errorbar(np.arange(len(df['id'])), df['Cq1Lala'], yerr=df['sdCq1Lala'], ls = 'None',
#      18              marker='o', color = 'r', markersize=8, label = 'Site 1')
#      19 plt.errorbar(np.arange(len(df['id'])), df['Cq2Lala'], yerr=df['sdCq2Lala'], ls = 'None',
#      20              marker='o', color = 'b', markersize=8, label = 'Site 2')
#      24 ax = plt.gca()
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(10,8), dpi=300)

# df = pd.DataFrame({"id":["this study", "computed", "Pike et. al."], 
#                   # etaq data
#                    "etaq1Lala":[0.34, 0.25, 0.28], 
#                    "etaq2Lala":[0.63,0.77, 0.7],
                   
#                    "sdetaq1Lala":[0.16,0,0.02],
#                    "sdetaq2Lala":[0.17,0,0.02]}
#                   )

plt.errorbar(np.arange(len(df['id'])), df['etaq1Lala'], yerr=df['sdetaq1Lala'], ls = 'None', 
             marker='o', color = 'r', markersize=8, label = 'Site 1')
plt.errorbar(np.arange(len(df['id'])), df['etaq2Lala'], yerr=df['sdetaq2Lala'], ls = 'None', 
             marker='o', color = 'b', markersize=8, label = 'Site 2')



ax = plt.gca()
ax.xaxis.set_ticks(np.arange(len(df['id'])))
ax.xaxis.set_ticklabels(df['id'], rotation=90, fontsize = 16)

# plt.xlabel("id", fontsize = 16)
plt.ylabel("etaq", fontsize = 16)

plt.legend(loc='upper left')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(8,8), dpi=200, sharex=True, sharey='row', constrained_layout=True)

# df = pd.DataFrame({"id":["Site 1", "Site 2"], 
#                  # Cq data
#                    "ourCq":[6.6, 6.5], 
#                    "pikeCq":[ 7.86, 6.53],
#                    "computedCq":[8.26, 6.28],
#                    "YamauchiCq":[8.1, 7.2],
#                    #error
#                    "sd_ourCq":[0.4, 0.4],
#                    "sd_pikeCq":[0.3, 0.3],
#                    "sd_computedCq":[0,0],
#                    "sd_YamauchiCq":[0.05, 0.05],
#                   #etaq data
#                   "ouretaq":[0.63, 0.34], 
#                    "pikeetaq":[0.28, 0.7],
#                    "computedetaq":[0.25, 0.77],
#                    "Yamauchietaq":[0, 0],
#                    #error
#                    "sd_ouretaq":[0.17, 0.16],
#                    "sd_pikeetaq":[0.02, 0.02],
#                    "sd_computedetaq":[0,0],
#                    "sd_Yamauchietaq":[0.0, 0.0]
                  
                  
#                     })

ax[0].errorbar(np.arange(len(df['id'])), df['ourCq'], yerr=df['sd_ourCq'], ls = 'None', 
             marker='o', color = 'red', markersize=8, ecolor='black', elinewidth=1, capsize=5, label = 'This study')
ax[0].errorbar(np.arange(len(df['id'])), df['pikeCq'], yerr=df['sd_pikeCq'], ls = 'None', 
             marker='s', color = 'darkorange', markersize=8, ecolor='black', elinewidth=1, capsize=5, label = 'Pike')
ax[0].errorbar(np.arange(len(df['id'])), df['computedCq'], yerr=df['sd_computedCq'], ls = 'None', 
             marker='X', color = 'magenta', markersize=8, ecolor='black', elinewidth=1, capsize=0, label = 'PBEsol+GIPAW')
ax[0].errorbar(np.arange(len(df['id'])), df['YamauchiCq'], yerr=df['sd_YamauchiCq'], ls = 'None', 
             marker='^', color = 'lime', markersize=8, ecolor='black', elinewidth=1, capsize=5, label = 'Yamauchi')

ax[1].errorbar(np.arange(len(df['id'])), df['ouretaq'], yerr=df['sd_ouretaq'], ls = 'None', 
             marker='o', color = 'red', markersize=8, ecolor='black', elinewidth=1, capsize=5, label = 'this study')
ax[1].errorbar(np.arange(len(df['id'])), df['pikeetaq'], yerr=df['sd_pikeetaq'], ls = 'None', 
             marker='s', color = 'darkorange', markersize=8, ecolor='black', elinewidth=1, capsize=5, label = 'pike')
ax[1].errorbar(np.arange(len(df['id'])), df['computedetaq'], yerr=df['sd_computedetaq'], ls = 'None', 
             marker='X', color = 'magenta', markersize=8, ecolor='black', elinewidth=1, capsize=0, label = 'comp')


ax[0].xaxis.set_ticks(np.arange(len(df['id'])))
ax[0].xaxis.set_ticklabels(df['id'], rotation=90, fontsize = 16)

# Remove top and right spines
ax[0].spines['top'].set_visible(False)
ax[0].spines['right'].set_visible(False)

ax[1].spines['top'].set_visible(False)
ax[1].spines['right'].set_visible(False)

# plt.xlabel("id", fontsize = 16)
ax[0].set_ylabel(r'$C_Q$ / MHz', fontsize = 16)

ax[1].set_ylabel(r'$\eta_Q$', fontsize = 16)

# get handles
handles, labels = ax[0].get_legend_handles_labels()
# remove the errorbars
handles = [h[0] for h in handles]
# use them in the legend
ax[0].legend(handles, labels, loc='upper right',numpoints=1)


# plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# **D-alanine Results**

# %%
# Cq Results for D-alanine
plt.figure(figsize=(10,8), dpi=300)

# df = pd.DataFrame({"id":["this study", "computed", "Wu and Dong"], 
#                  # Cq data
#                    "Cq1Dala":[7.1, 8.26, 7.6], 
#                    "Cq2Dala":[5.91, 6.28, 6.4],
                   
#                    "sdCq1Dala":[0.2,0,0.02],
#                    "sdCq2Dala":[0.13,0,0.02]}
#                   )

plt.errorbar(np.arange(len(df['id'])), df['Cq1Dala'], yerr=df['sdCq1Dala'], ls = 'None', 
             marker='o', color = 'r', markersize=8, label = 'Site 1')
plt.errorbar(np.arange(len(df['id'])), df['Cq2Dala'], yerr=df['sdCq2Dala'], ls = 'None', 
             marker='o', color = 'b', markersize=8, label = 'Site 2')



ax = plt.gca()
ax.xaxis.set_ticks(np.arange(len(df['id'])))
ax.xaxis.set_ticklabels(df['id'], rotation=90, fontsize = 16)

# plt.xlabel("id", fontsize = 16)
plt.ylabel("Cq / MHz", fontsize = 16)

plt.legend(loc='upper right')
plt.show()

# %%
plt.figure(figsize=(10,8), dpi=300)

# df = pd.DataFrame({"id":["this study", "computed", "Wu and Dong"], 
#                   # etaq data
#                    "etaq1Dala":[0.24, 0.25, 0.6], 
#                    "etaq2Dala":[0.7,0.77, 0.65],
                   
#                    "sdetaq1Dala":[0.09,0,0.01],
#                    "sdetaq2Dala":[0.06,0,0.01]}
#                   )

plt.errorbar(np.arange(len(df['id'])), df['etaq1Dala'], yerr=df['sdetaq1Dala'], ls = 'None', 
             marker='o', color = 'r', markersize=8, label = 'Site 1')
plt.errorbar(np.arange(len(df['id'])), df['etaq2Dala'], yerr=df['sdetaq2Dala'], ls = 'None', 
             marker='o', color = 'b', markersize=8, label = 'Site 2')



ax = plt.gca()
ax.xaxis.set_ticks(np.arange(len(df['id'])))
ax.xaxis.set_ticklabels(df['id'], rotation=90, fontsize = 16)

# plt.xlabel("id", fontsize = 16)
plt.ylabel("etaq", fontsize = 16)

plt.legend(loc='upper right')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(8,8), dpi=200, sharex=True, sharey='row', constrained_layout=True)

# df = pd.DataFrame({"id":["Site 1", "Site 2"], 
#                  # Cq data
#                    "ourCq":[7.1, 5.91], 
#                    "WuCq":[ 7.6, 6.4],
#                    "computedCq":[8.26, 6.28],
                   
#                    #error
#                    "sd_ourCq":[0.2, 0.13],
#                    "sd_WuCq":[0.02, 0.02],
#                    "sd_computedCq":[0,0],
                   
#                   #etaq data
#                   "ouretaq":[0.24, 0.7], 
#                    "Wuetaq":[0.6, 0.65],
#                    "computedetaq":[0.25, 0.77],
               
#                    #error
#                    "sd_ouretaq":[0.09, 0.06],
#                    "sd_Wuetaq":[0.01, 0.01],
#                    "sd_computedetaq":[0,0],
               
                  
                  
#                     })

ax[0].errorbar(np.arange(len(df['id'])), df['ourCq'], yerr=df['sd_ourCq'], ls = 'None', 
             marker='o', color = 'red', markersize=8, ecolor='black', elinewidth=1, capsize=5, label = 'This study')
ax[0].errorbar(np.arange(len(df['id'])), df['WuCq'], yerr=df['sd_WuCq'], ls = 'None', 
             marker='*', color = 'blue', markersize=10, ecolor='black', elinewidth=1, capsize=5, label = 'Wu and Dong')
ax[0].errorbar(np.arange(len(df['id'])), df['computedCq'], yerr=df['sd_computedCq'], ls = 'None', 
             marker='X', color = 'magenta', markersize=8, ecolor='black', elinewidth=1, capsize=0, label = 'PBEsol + GIPAW')


ax[1].errorbar(np.arange(len(df['id'])), df['ouretaq'], yerr=df['sd_ouretaq'], ls = 'None', 
             marker='o', color = 'red', markersize=8, ecolor='black', elinewidth=1, capsize=5, label = 'our')
ax[1].errorbar(np.arange(len(df['id'])), df['Wuetaq'], yerr=df['sd_Wuetaq'], ls = 'None', 
             marker='*', color = 'blue', markersize=10, ecolor='black', elinewidth=1, capsize=5, label = 'Wu')
ax[1].errorbar(np.arange(len(df['id'])), df['computedetaq'], yerr=df['sd_computedetaq'], ls = 'None', 
             marker='X', color = 'magenta', markersize=8, ecolor='black', elinewidth=1, capsize=0, label = 'comp')



ax[0].xaxis.set_ticks(np.arange(len(df['id'])))
ax[0].xaxis.set_ticklabels(df['id'], rotation=90, fontsize = 16)

# Remove top and right spines
ax[0].spines['top'].set_visible(False)
ax[0].spines['right'].set_visible(False)

ax[1].spines['top'].set_visible(False)
ax[1].spines['right'].set_visible(False)

# plt.xlabel("id", fontsize = 16)
ax[0].set_ylabel(r'$C_Q$ / MHz', fontsize = 16)

ax[1].set_ylabel(r'$\eta_Q$', fontsize = 16)

# get handles
handles, labels = ax[0].get_legend_handles_labels()
# remove the errorbars
handles = [h[0] for h in handles]
# use them in the legend
ax[0].legend(handles, labels, loc='upper right',numpoints=1)


# plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# **Combined**

# %%
# Using latest CASTEP calculations for this plot
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(8,6), dpi=200, sharex=True, sharey='row', constrained_layout=True)

sample = ['L-alanine', 'D-alanine']

df = [pd.DataFrame({"id":["Site 1", "Site 2"], 
                 # Cq data
                   "ourCq":[6.5, 6.6], 
                   "pikeCq":[ 7.86, 6.53],
                   "computedCq":[8.34, 6.36],
                   "YamauchiCq":[8.1, 7.2],
                   #error
                   "sd_ourCq":[0.4, 0.4],
                   "sd_pikeCq":[0.3, 0.3],
                   "sd_computedCq":[0,0],
                   "sd_YamauchiCq":[0.05, 0.05],
                  #etaq data
                  "ouretaq":[0.34, 0.63], 
                   "pikeetaq":[0.28, 0.7],
                   "computedetaq":[0.25, 0.77],
                   "Yamauchietaq":[0, 0],
                   #error
                   "sd_ouretaq":[0.16, 0.17],
                   "sd_pikeetaq":[0.02, 0.02],
                   "sd_computedetaq":[0,0],
                   "sd_Yamauchietaq":[0.0, 0.0]
                  
                  
                    }),

pd.DataFrame({"id":["Site 1", "Site 2"], 
                 # Cq data
                   "ourCq":[7.1, 5.91], 
                   "WuCq":[ 7.6, 6.4],
                   "computedCq":[8.34	,	6.36],
                   
                   #error
                   "sd_ourCq":[0.2, 0.13],
                   "sd_WuCq":[0.02, 0.02],
                   "sd_computedCq":[0,0],
                   
                  #etaq data
                  "ouretaq":[0.24, 0.7], 
                   "Wuetaq":[0.6, 0.65],
                   "computedetaq":[0.25, 0.77],
               
                   #error
                   "sd_ouretaq":[0.09, 0.06],
                   "sd_Wuetaq":[0.01, 0.01],
                   "sd_computedetaq":[0,0],
               
                  
                  
                    })]

#title for plots
ax[0,0].set_title(sample[0], fontweight='bold') 
ax[0,1].set_title(sample[1], fontweight='bold')

x = np.arange(len(df[0]['id']))

offset = 0.2
num_lala_data = 4                                       # Number of  data points
num_dala_data = 3                                       # Number of  data points

#Cq data
i_lala = np.linspace(-offset*(num_lala_data//2), offset*(num_lala_data//2), num_lala_data )
i_dala = np.linspace(-offset*(num_dala_data//2), offset*(num_dala_data//2), num_dala_data)

#**************L-alanine********************

#Cq data
ax[0,0].errorbar(x  + i_lala[0]*offset, df[0]['ourCq'], yerr=df[0]['sd_ourCq'], ls = 'None', 
             marker='o', color = 'red', markersize=8, elinewidth=1, capsize=5, label = 'This study')
ax[0,0].errorbar(x  + i_lala[1]*offset, df[0]['pikeCq'], yerr=df[0]['sd_pikeCq'], ls = 'None', 
             marker='s', color = 'darkorange', markersize=8,  elinewidth=1, capsize=5, label = 'Pike')

ax[0,0].errorbar(x  + i_lala[2]*offset, df[0]['YamauchiCq'], yerr=df[0]['sd_YamauchiCq'], ls = 'None', 
             marker='^', color = 'lime', markersize=8,  elinewidth=1, capsize=5, label = 'Yamauchi')
ax[0,0].errorbar(x  + i_lala[3]*offset, df[0]['computedCq'], yerr=df[0]['sd_computedCq'], ls = 'None', 
             marker='X', color = 'magenta', markersize=8,  elinewidth=1, capsize=0, label = 'PBEsol+GIPAW\n(Computational)')
#etaq data
ax[1,0].errorbar(x  + i_lala[0]*offset, df[0]['ouretaq'], yerr=df[0]['sd_ouretaq'], ls = 'None', 
             marker='o', color = 'red', markersize=8,  elinewidth=1, capsize=5, label = 'this study')
ax[1,0].errorbar(x  + i_lala[1]*offset, df[0]['pikeetaq'], yerr=df[0]['sd_pikeetaq'], ls = 'None', 
             marker='s', color = 'darkorange', markersize=8,  elinewidth=1, capsize=5, label = 'pike')
ax[1,0].errorbar(x  + i_lala[2]*offset, df[0]['computedetaq'], yerr=df[0]['sd_computedetaq'], ls = 'None', 
             marker='X', color = 'magenta', markersize=8,  elinewidth=1, capsize=0, label = 'comp')

#**************D-alanine********************

ax[0,1].errorbar(x  + i_dala[0]*offset, df[1]['ourCq'], yerr=df[1]['sd_ourCq'], ls = 'None', 
             marker='o', color = 'red', markersize=8,  elinewidth=1, capsize=5, label = 'This study')
ax[0,1].errorbar(x  + i_dala[1]*offset, df[1]['WuCq'], yerr=df[1]['sd_WuCq'], ls = 'None', 
             marker='*', color = 'blue', markersize=10,  elinewidth=1, capsize=5, label = 'Wu and Dong')
ax[0,1].errorbar(x  + i_dala[2]*offset, df[1]['computedCq'], yerr=df[1]['sd_computedCq'], ls = 'None', 
             marker='X', color = 'magenta', markersize=8, elinewidth=1, capsize=0, label = 'PBEsol+GIPAW\n(Computational)')


ax[1,1].errorbar(x  + i_dala[0]*offset, df[1]['ouretaq'], yerr=df[1]['sd_ouretaq'], ls = 'None', 
             marker='o', color = 'red', markersize=8, elinewidth=1, capsize=5, label = 'our')
ax[1,1].errorbar(x  + i_dala[1]*offset, df[1]['Wuetaq'], yerr=df[1]['sd_Wuetaq'], ls = 'None', 
             marker='*', color = 'blue', markersize=10,  elinewidth=1, capsize=5, label = 'Wu')
ax[1,1].errorbar(x  + i_dala[2]*offset, df[1]['computedetaq'], yerr=df[1]['sd_computedetaq'], ls = 'None', 
             marker='X', color = 'magenta', markersize=8, elinewidth=1, capsize=0, label = 'comp')


ax[0,0].xaxis.set_ticks(np.arange(len(df[0]['id'])))
ax[0,0].xaxis.set_ticklabels(df[0]['id'], rotation=90, fontsize = 16)

ax[0,0].set_ylabel(r'$C_Q$ / MHz', fontsize = 16)

ax[1,0].set_ylabel(r'$\eta_Q$', fontsize = 16)

# get handles
handles_Lala, labels_Lala = ax[0,0].get_legend_handles_labels()
handles_Dala, labels_Dala = ax[0,1].get_legend_handles_labels()
# remove the errorbars
handles_Lala = [h[0] for h in handles_Lala]
handles_Dala = [h[0] for h in handles_Dala]

# use them in the legend
ax[0,0].legend(handles_Lala, labels_Lala, loc='center',bbox_to_anchor=(0.5, 0.7), numpoints=1)

ax[0,1].legend(handles_Dala, labels_Dala, loc='center',bbox_to_anchor=(0.5, 0.7), numpoints=1)

# plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# **Combined Version II**
#
# *This version includes shift of data points on x-axis*

# %%
# Using latest CASTEP calculations for this plot
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,8), dpi=200, sharex=True, sharey='row', constrained_layout=True)

sample = ['L-alanine', 'D-alanine']

df = [pd.DataFrame({"id":["Site 1", "Site 2"], 
                 # Cq data
                   "ourCq":[6.5, 6.6], 
                   "pikeCq":[ 7.86, 6.53],
                   "computedCq":[8.09, 6.49],
                   "YamauchiCq":[8.1, 7.2],
                   #error
                   "sd_ourCq":[0.4, 0.4],
                   "sd_pikeCq":[0.3, 0.3],
                   "sd_computedCq":[0,0],
                   "sd_YamauchiCq":[0.05, 0.05],
                  #etaq data
                  "ouretaq":[0.34, 0.63], 
                   "pikeetaq":[0.28, 0.7],
                   "computedetaq":[0.22, 0.65],
                   "Yamauchietaq":[0, 0],
                   #error
                   "sd_ouretaq":[0.16, 0.17],
                   "sd_pikeetaq":[0.02, 0.02],
                   "sd_computedetaq":[0,0],
                   "sd_Yamauchietaq":[0.0, 0.0]
                  
                  
                    }),

pd.DataFrame({"id":["Site 1", "Site 2"], 
                 # Cq data
                   "ourCq":[7.1, 5.91], 
                   "WuCq":[ 7.6, 6.4],
                   "computedCq":[8.09, 6.49],
                   
                   #error
                   "sd_ourCq":[0.2, 0.13],
                   "sd_WuCq":[0.02, 0.02],
                   "sd_computedCq":[0,0],
                   
                  #etaq data
                  "ouretaq":[0.24, 0.7], 
                   "Wuetaq":[0.6, 0.65],
                   "computedetaq":[0.22, 0.65],
               
                   #error
                   "sd_ouretaq":[0.09, 0.06],
                   "sd_Wuetaq":[0.01, 0.01],
                   "sd_computedetaq":[0,0],
               
                  
                  
                    })]

#title for plots
ax[0,0].set_title(sample[0], fontweight='bold') 
ax[0,1].set_title(sample[1], fontweight='bold')

x = np.arange(len(df[0]['id']))

offset = 0.3
num_lala_data = 3                                       # Number of experimental data points
num_dala_data = 2                                       # Number of experimental data points

#Cq data
i_lala = np.linspace(-offset*(num_lala_data//2), offset*(num_lala_data//2), num_lala_data )
i_dala = np.linspace(-offset*(num_dala_data//2), offset*(num_dala_data//2), num_dala_data)

#**************L-alanine********************

    
ax[0,0].errorbar(x  + i_lala[0]*offset, df[0]['ourCq'], yerr=df[0]['sd_ourCq'], ls = 'None', 
            marker='o', color = 'red', markersize=8, elinewidth=1,  label = 'This study')
ax[0,0].errorbar(x  + i_lala[1]*offset, df[0]['pikeCq'], yerr=df[0]['sd_pikeCq'], ls = 'None', 
            marker='s', color = 'darkorange', markersize=8,  elinewidth=1,  label = 'Pike et al.')
ax[0,0].errorbar(x + i_lala[2]*offset, df[0]['YamauchiCq'], yerr=df[0]['sd_YamauchiCq'], ls = 'None', 
            marker='^', color = 'lime', markersize=8,  elinewidth=1,  label = 'Yamauchi et al.')

# Plot computed result as a bar
ax[0,0].plot(x[0] + i_lala, np.full_like(x[0] + i_lala, df[0]['computedCq'][0]), color='magenta', linewidth=1, linestyle='-', label='PBEsol+GIPAW\n(Computational)')
ax[0,0].plot(x[1] + i_lala, np.full_like(x[1] + i_lala, df[0]['computedCq'][1]), color='magenta', linewidth=1, linestyle='-')



#etaq data
ax[1,0].errorbar(x+ i_lala[0]*offset, df[0]['ouretaq'], yerr=df[0]['sd_ouretaq'], ls = 'None', 
            marker='o', color = 'red', markersize=8,  elinewidth=1, label = 'this study')
ax[1,0].errorbar(x+ i_lala[1]*offset, df[0]['pikeetaq'], yerr=df[0]['sd_pikeetaq'], ls = 'None', 
            marker='s', color = 'darkorange', markersize=8,  elinewidth=1, label = 'pike')

# Plot computed result as a bar
ax[1,0].plot(x[0] + i_lala, np.full_like(x[0] + i_lala, df[0]['computedetaq'][0]), color='magenta', linewidth=1, linestyle='-', label='PBEsol+GIPAW\n(Computational)')
ax[1,0].plot(x[1] + i_lala, np.full_like(x[0] + i_lala, df[0]['computedetaq'][1]), color='magenta', linewidth=1, linestyle='-')


#**************D-alanine********************

ax[0,1].errorbar(x + i_dala[0]*offset, df[1]['ourCq'], yerr=df[1]['sd_ourCq'], ls = 'None', 
             marker='o', color = 'red', markersize=8,  elinewidth=1, label = 'This study')
ax[0,1].errorbar(x + i_dala[1]*offset, df[1]['WuCq'], yerr=df[1]['sd_WuCq'], ls = 'None', 
             marker='*', color = 'blue', markersize=10,  elinewidth=1,  label = 'Wu et al.')
# Plot computed result as a bar
ax[0,1].plot(x[0] + i_dala, np.full_like(x[0] + i_dala, df[0]['computedCq'][0]), color='magenta', linewidth=1, linestyle='-', label='PBEsol+GIPAW\n(Computational)')
ax[0,1].plot(x[1] + i_dala, np.full_like(x[1] + i_dala, df[0]['computedCq'][1]), color='magenta', linewidth=1, linestyle='-')


ax[1,1].errorbar(x + i_dala[0]*offset, df[1]['ouretaq'], yerr=df[1]['sd_ouretaq'], ls = 'None', 
             marker='o', color = 'red', markersize=8, elinewidth=1,  label = 'our')
ax[1,1].errorbar(x + i_dala[1]*offset, df[1]['Wuetaq'], yerr=df[1]['sd_Wuetaq'], ls = 'None', 
             marker='*', color = 'blue', markersize=10,  elinewidth=1,  label = 'Wu')
# Plot computed result as a bar
ax[1,1].plot(x[0] + i_dala, np.full_like(x[0] + i_dala, df[0]['computedetaq'][0]), color='magenta', linewidth=1, linestyle='-', label='PBEsol+GIPAW\n(Computational)')
ax[1,1].plot(x[1] + i_dala, np.full_like(x[1] + i_dala, df[0]['computedetaq'][1]), color='magenta', linewidth=1, linestyle='-')

ax[0,0].set_xticks(x)
ax[0,0].set_xticklabels(df[0]['id'], rotation=90, fontsize = 16)

ax[0,0].set_ylabel(r'$C_Q$ / MHz', fontsize = 16)

ax[1,0].set_ylabel(r'$\eta_Q$', fontsize = 16)


# get handles
handles_Lala, labels_Lala = ax[0,0].get_legend_handles_labels()
handles_Dala, labels_Dala = ax[0,1].get_legend_handles_labels()



# use them in the legend
ax[0,0].legend(handles_Lala, labels_Lala, loc='upper right', numpoints=1, fontsize = 10)

ax[0,1].legend(handles_Dala, labels_Dala, loc='upper right', numpoints=1, fontsize = 10)

# plt.legend(loc='upper right')
# ax[0,1].legend(handles_Dala, labels_Dala, loc='center',bbox_to_anchor=(0.78, 0.87), numpoints=1, fontsixe = 10)

fig.savefig('/home/shiva/WMU/PhD/Scripts/phd_project/Python/NMR/NMR_analysis/plots_experiment/alanine_results.png', dpi = 150 ,bbox_inches='tight')

# Show the plot
plt.show()

# %%
print(i_lala)
print(x[0] + i_lala)

print(df[0]['computedCq'][0])

np.full_like(x[0] + i_lala, df[0]['computedCq'][0])

print(h[0] for h in handles_Lala)
# Out:
# [-0.2  0.   0.2]
# [-0.2  0.   0.2]
# 8.26
# <generator object <genexpr> at 0x7fe84778a8f0>

# %%
# Out:
# 2
