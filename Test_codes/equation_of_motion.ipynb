# %%
def acce(u, v, s):
 a = (v**2 - u**2) / (2*s)
 return a

# %%
initial_u = 1*10**5
final_v = 2.5*10**6
dist = 1.5*10**-2

acceleration = acce(initial_u, final_v, dist)
print("{:e}".format(acceleration))
# Out:
# 2.080000e+14
